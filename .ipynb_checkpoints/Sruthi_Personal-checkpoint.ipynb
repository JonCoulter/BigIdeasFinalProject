# %% [markdown]
# ## Introduction
# Our ultimate goal is to determine which neighborhood is the most environmentally friendly. The goal of my individual notebook is to determine which neighborhoods have the highest amount of trees, a large variety or trees, and the greatest amount of trees per square foot of the neighborhood. To determine these metrics, I used the Trees and Neighborhood datasets.

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
# %matplotlib inline

#DataFrame for the entire Trees dataset.
treesData = pd.read_csv("Trees.csv", low_memory = False)

treesData.head(10) #imported trees data file
# Out:
#            id address_number         street               common_name  \
# 0   754166088           7428  MONTICELLO ST                     Stump
# 1  1946899269            220     BALVER AVE        Linden: Littleleaf
# 2  1431517397           2822      SIDNEY ST                Maple: Red
# 3   994063598            608     SUISMON ST            Maple: Freeman
# 4  1591838573           1135   N NEGLEY AVE             Maple: Norway
# 5  1333224197           5550      BRYANT ST                  Oak: Pin
# 6   239290336           5503      BRYANT ST  Dogwood: Corneliancherry
# 7  1233652274           1207       KING AVE             Maple: Norway
# 8  1477030894           1201       KING AVE             Maple: Norway
# 9  1484901843           1456    WOODBINE ST             Maple: Norway
#
#      scientific_name  height  width  growth_space_length  growth_space_width  \
# 0              Stump     0.0    0.0                 10.0                 2.0
# 1      Tilia cordata     0.0    0.0                 99.0                99.0
# 2        Acer rubrum    22.0    6.0                  6.0                 3.0
# 3   Acer x freemanii    25.0   10.0                  3.0                 3.0
# 4   Acer platanoides    52.0   13.0                 99.0                99.0
# 5  Quercus palustris    45.0   18.0                 35.0                 3.0
# 6         Cornus mas     8.0    4.0                 99.0                 3.0
# 7   Acer platanoides    27.0   10.0                 30.0                 3.0
# 8   Acer platanoides    35.0   12.0                  3.0                 3.0
# 9   Acer platanoides     NaN    NaN                  NaN                 NaN
#
#       growth_space_type  ...      neighborhood  council_district  ward  \
# 0           Well or Pit  ...    Homewood North               9.0  13.0
# 1  Open or Unrestricted  ...           Oakwood               2.0  28.0
# 2           Well or Pit  ...  South Side Flats               3.0  16.0
# 3           Well or Pit  ...    East Allegheny               1.0  23.0
# 4  Open or Unrestricted  ...     Highland Park               7.0  11.0
# 5  Tree Lawn or Parkway  ...     Highland Park               7.0  11.0
# 6  Tree Lawn or Parkway  ...     Highland Park               7.0  11.0
# 7  Tree Lawn or Parkway  ...     Highland Park               7.0  11.0
# 8           Well or Pit  ...     Highland Park               7.0  11.0
# 9  Open or Unrestricted  ...   Stanton Heights               7.0  10.0
#
#           tract public_works_division  pli_division  police_zone  fire_zone  \
# 0  4.200313e+10                   2.0          13.0          5.0       3-17
# 1  4.200356e+10                   5.0          28.0          6.0       1-19
# 2  4.200316e+10                   3.0          16.0          3.0       4-24
# 3  4.200356e+10                   1.0          23.0          1.0        1-6
# 4  4.200311e+10                   2.0          11.0          5.0        3-9
# 5  4.200311e+10                   2.0          11.0          5.0        3-9
# 6  4.200311e+10                   2.0          11.0          5.0        3-9
# 7  4.200311e+10                   2.0          11.0          5.0        3-9
# 8  4.200311e+10                   2.0          11.0          5.0        3-9
# 9  4.200310e+10                   2.0          10.0          5.0        3-7
#
#     latitude  longitude
# 0  40.458169 -79.889724
# 1  40.429269 -80.067868
# 2  40.426797 -79.965035
# 3  40.455503 -79.999276
# 4  40.476667 -79.924106
# 5  40.477496 -79.924568
# 6  40.478403 -79.925985
# 7  40.478404 -79.926126
# 8  40.478314 -79.926161
# 9  40.485240 -79.936390
#
# [10 rows x 58 columns]

# %%
#create dictionary to find out how many trees are in each neighborhood
treesdict = {}

#looping through the dataframe of the entire trees dataset and adding up all instances where the neighborhood appears
#to determine how many trees per neighborhood
for index, row in treesData.iterrows():
    if row['neighborhood'] in treesdict.keys():
        treesdict[row['neighborhood']] += 1
    else:
        treesdict[row['neighborhood']] = 1

#ignore (unnecessary)
#treelist = []
#for row['neighborhood'] in treesdict:
#    treelist.append(treesdict[row['neighborhood']])
    
#treelist.sort()
#print(treesdict)

#print(treelist)

# %%
#num_trees = treesData.groupby("neighborhood").sum()
#num_trees.sort_values(by='neighborhood')

#dataframe with the number of trees for each neighborhood
treesDf = pd.DataFrame(treesdict.items(), columns = ['Neighborhood','Number_of_trees'])

treesDf.head()
# Out:
#        Neighborhood  Number_of_trees
# 0    Homewood North              403
# 1           Oakwood               92
# 2  South Side Flats             1693
# 3    East Allegheny              391
# 4     Highland Park             2941

# %%
#a graph of the neighborhoods without the tree data
neighborhoods = geopandas.read_file("Neighborhoods_.shp") # read in the shapefile
neighborhoods.plot() # plot the geopandas dataframe

# %%
#orders the number of trees for each neighborhood in descending order
num_trees = treesDf.groupby("Neighborhood").sum()['Number_of_trees']
num_trees.sort_values(ascending=False)
# Out:
# Neighborhood
# Squirrel Hill South    5073
# Highland Park          2941
# Squirrel Hill North    2083
# South Side Flats       1693
# Shadyside              1558
#                        ...
# Arlington Heights         5
# Esplen                    3
# Glen Hazel                2
# South Shore               2
# Hays                      1
# Name: Number_of_trees, Length: 90, dtype: int64

# %%
# merges the num_trees to create the map
trees_map = neighborhoods.merge(num_trees, how='left', left_on='hood', right_on='Neighborhood')

# look at the head to confirm it merged correctly
trees_map[['hood','Number_of_trees','geometry']].head()
# Out:
#                hood  Number_of_trees  \
# 0   Central Oakland              368
# 1     North Oakland              775
# 2      West Oakland               78
# 3  Crawford-Roberts              568
# 4    Strip District              486
#
#                                             geometry
# 0  POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 1  POLYGON ((-79.95455 40.45882, -79.95427 40.458...
# 2  POLYGON ((-79.96230 40.44294, -79.96220 40.442...
# 3  POLYGON ((-79.98275 40.44641, -79.98273 40.446...
# 4  POLYGON ((-79.97494 40.45629, -79.97484 40.456...

# %%
#map of the neighborhoods and the tree distribution
trees_map.plot(column='Number_of_trees')

# %%
# set a variable that will call whatever column we want to visualise on the map
variable = 'Number_of_trees'
# set the range for the choropleth
vmin, vmax = 120, 220
fig, ax = plt.subplots(1, figsize=(10, 6))

#color codes and labels the map for easy visualization
trees_map.plot(column=variable, cmap='Greens', legend = True, legend_kwds={'label': "Number of Trees"}, 
               linewidth=0.8,ax=ax,figsize=(15, 10), edgecolor='0.8')
ax.set_title('Tree Distribution Across Pittsburgh', fontdict={'fontsize': '25', 'fontweight' : '3'})
# Out:
# Text(0.5, 1.0, 'Tree Distribution Across Pittsburgh')

# %%
#dictionary for the variety of trees
treeVarDict = {}

#loops through the entire dataframe for Trees.csv
for index, row in treesData.iterrows():
    if row['neighborhood'] not in treeVarDict:
        #creates a list and stores the variety of tree for each neighborhood
        treeVarDict[row['neighborhood']] = list()
    elif row['scientific_name'] in treeVarDict[row['neighborhood']]:
        #if the variety of the tree already exists in the list for the variable nothing happens
        rand = 0
    else:
        #if the variety of the tree does not already exist in the list for the variable then the variety is added to the list
        treeVarDict[row['neighborhood']].append(row['scientific_name'])
        
#print(treeVarDict)

# %%
#dataframe for the neighborhoods and the different variety of trees in the neighborhood
treesVarDf = pd.DataFrame(treeVarDict.items(), columns = ['Neighborhood','Type of Tree'])

treesVarDf.head()
# Out:
#        Neighborhood                                       Type of Tree
# 0    Homewood North  [Tilia tomentosa, Quercus palustris, Platanus ...
# 1           Oakwood  [Acer rubrum, Cornus florida, Acer platanoides...
# 2  South Side Flats  [Acer rubrum, Malus spp., Platanus x acerifoli...
# 3    East Allegheny  [Gleditsia triacanthos inermis, Ginkgo biloba,...
# 4     Highland Park  [Quercus palustris, Cornus mas, Acer platanoid...

# %%
#dictionary for the count of different type of trees in each neighborhood
typeDict = {}

#loops through the treesVarDf to count up the types of trees in each neighborhood
for index, row in treesVarDf.iterrows():
    typeDict[row['Neighborhood']] = len(row['Type of Tree'])

#print(typeDict)

# %%
#dataframe for the number of different tree types for each neighborhood
typeNumDf = pd.DataFrame(typeDict.items(), columns = ['Neighborhood','# of Different Tree Types'])

typeNumDf.head()
# Out:
#        Neighborhood  # of Different Tree Types
# 0    Homewood North                         44
# 1           Oakwood                         29
# 2  South Side Flats                         73
# 3    East Allegheny                         40
# 4     Highland Park                        137

# %%
#orders the number of types for each neighborhood in descending order
num_type = typeNumDf.groupby("Neighborhood").sum()['# of Different Tree Types']
num_type.sort_values(ascending=False)
# Out:
# Neighborhood
# Squirrel Hill South    143
# Highland Park          137
# Squirrel Hill North     91
# Point Breeze            85
# East Liberty            79
#                       ...
# Arlington Heights        4
# Esplen                   2
# South Shore              1
# Glen Hazel               1
# Hays                     0
# Name: # of Different Tree Types, Length: 90, dtype: int64

# %%
# do the merge
type_map = neighborhoods.merge(num_type, how='left', left_on='hood', right_on='Neighborhood')
# look at the head to confirm it merged correctly
type_map[['hood','# of Different Tree Types','geometry']].head()
# Out:
#                hood  # of Different Tree Types  \
# 0   Central Oakland                         44
# 1     North Oakland                         57
# 2      West Oakland                         27
# 3  Crawford-Roberts                         34
# 4    Strip District                         35
#
#                                             geometry
# 0  POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 1  POLYGON ((-79.95455 40.45882, -79.95427 40.458...
# 2  POLYGON ((-79.96230 40.44294, -79.96220 40.442...
# 3  POLYGON ((-79.98275 40.44641, -79.98273 40.446...
# 4  POLYGON ((-79.97494 40.45629, -79.97484 40.456...

# %%
# set a variable that will call whatever column we want to visualise on the map
variable = '# of Different Tree Types'
# set the range for the choropleth
vmin, vmax = 120, 220
fig, ax = plt.subplots(1, figsize=(10, 6))

#color codes and labels the map for easy visualization
type_map.plot(column=variable, cmap='Reds', legend = True, legend_kwds={'label': "'# of Different Tree Types"}, 
               linewidth=0.8,ax=ax,figsize=(15, 10), edgecolor='0.8')
ax.set_title('Tree Variety Distribution Across Pittsburgh', fontdict={'fontsize': '25', 'fontweight' : '3'})
# Out:
# Text(0.5, 1.0, 'Tree Variety Distribution Across Pittsburgh')

# %%
#dataframe for the size of each neighborhood
nbhd_sizes = pd.read_table("NeighborhoodSizes.csv", sep = ",")

nbhd_sizes.head()
# Out:
#    objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0         1         233        42        003    140500          3
# 1         2         203        42        003    140100          3
# 2         3          86        42        003    101700          2
# 3         4         214        42        003    050900          1
# 4         5         173        42        003    300100          5
#
#         geoid10     namelsad10 mtfcc10 funcstat10  ...  page_number  \
# 0  420031405003  Block Group 3   G5030          S  ...           15
# 1  420031401003  Block Group 3   G5030          S  ...           15
# 2  420031017002  Block Group 2   G5030          S  ...           15
# 3  420030509001  Block Group 1   G5030          S  ...           15
# 4  420033001005  Block Group 5   G5030          S  ...           15
#
#     plannerassign                              globalid created_user  \
# 0   Ose Akinlotan  a642a6b6-a2a9-48d5-acf2-3e2ce87d4bc0          SDE
# 1   Ose Akinlotan  20d4605b-258e-441a-a57e-a28fdabb6d30          SDE
# 2   Ose Akinlotan  bf4065e7-c29c-48bd-b529-e7fd99077238          SDE
# 3   Ose Akinlotan  fed3fb32-0cd3-4556-aa41-17ee03b4fe41          SDE
# 4  Thomas Scharff  8669d2f0-b886-4519-99d0-bb1015b592b0          SDE
#
#           created_date  last_edited_user     last_edited_date  temp  \
# 0  2020-08-14T12:57:28               SDE  2020-08-14T13:02:13   NaN
# 1  2020-08-14T12:57:28               SDE  2020-08-14T13:02:41   NaN
# 2  2020-08-14T12:57:28               SDE  2020-08-14T12:59:55   NaN
# 3  2020-08-14T12:57:28               SDE  2020-08-14T12:58:41   NaN
# 4  2020-08-14T12:57:28               SDE  2020-08-14T13:00:19   NaN
#
#      shape_area  shape_length
# 0  8.153647e+06  14047.065024
# 1  3.407739e+07  30347.886823
# 2  1.275116e+07  14577.441571
# 3  4.997845e+06  14216.959213
# 4  8.410563e+06  12003.269761
#
# [5 rows x 39 columns]

# %%
# looping through NeighborhoodSizes.csv to create dictionary with each neighborhood's size in acres
for index, row in nbhd_sizes.iterrows():
    if row["hood"] in size_dict:
        nbhd_size_dict[row["hood"]] = row["acres"]

# %%
#data frame for number of trees per square foot
treeSF_dict = {}

for index, row in nbhd_sizes.iterrows():
    if row["hood"] not in treeSF_dict.keys():
        treeSF_dict[row["hood"]] = (treesDf['Number_of_trees']/nbhd_sizes["acres"])
        
    if nbhd_size_dict[neighborhood] != 0:
        nbhd_dict["percent_park_area"].append(size_dict[neighborhood] / nbhd_size_dict[neighborhood] * 100)
    else:
        nbhd_dict["percent_park_area"].append(0)
        
print(treeSF_dict)
# Out:
# {'Point Breeze North': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Squirrel Hill North': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Garfield': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Bedford Dwellings': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Knoxville': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Homewood South': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Middle Hill': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Oakwood': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'North Oakland': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Duquesne Heights': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Glen Hazel': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'East Liberty': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Westwood': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Morningside': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Lincoln Place': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Perry North': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Northview Heights': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Homewood North': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Arlington Heights': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Lower Lawrenceville': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Larimer': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Lincoln-Lemington-Belmar': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Bluff': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Fairywood': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Brookline': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Hays': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Beltzhoover': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Greenfield': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'East Carnegie': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'North Shore': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Allentown': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Bon Air': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Allegheny West': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Crafton Heights': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Manchester': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Marshall-Shadeland': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Highland Park': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'New Homestead': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Central Northside': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Polish Hill': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Overbrook': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Friendship': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Homewood West': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Central Business District': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'East Allegheny': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Allegheny Center': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Central Oakland': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Brighton Heights': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'South Side Slopes': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Arlington': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Chartiers City': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Carrick': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Bloomfield': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Banksville': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Mount Washington': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'East Hills': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Central Lawrenceville': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'West End': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Esplen': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Point Breeze': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Hazelwood': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Crawford-Roberts': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'South Oakland': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Upper Hill': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Ridgemont': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Troy Hill': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'South Shore': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Mt. Oliver': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'California-Kirkbride': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Spring Hill-City View': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Sheraden': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Stanton Heights': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Beechview': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'St. Clair': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Chateau': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Shadyside': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Summer Hill': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'West Oakland': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Windgap': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Spring Garden': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Squirrel Hill South': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Strip District': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Swisshelm Park': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Perry South': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Upper Lawrenceville': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Regent Square': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Terrace Village': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Elliott': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'South Side Flats': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64, 'Fineview': 0      2.192827
# 1      0.117056
# 2      5.756996
# 3      3.392566
# 4     15.161201
#         ...
# 86     0.059149
# 87     0.015390
# 88     0.430552
# 89     0.012462
# 90          NaN
# Length: 91, dtype: float64}

# %%
data = pd.DataFrame(treeSF_dict)
data = data.set_index("hood")
data = data.sort_values(by = ["percent_park_area"], ascending = False)
# Out:
#    Point Breeze North  Squirrel Hill North   Garfield  Bedford Dwellings  \
# 0            2.192827             2.192827   2.192827           2.192827
# 1            0.117056             0.117056   0.117056           0.117056
# 2            5.756996             5.756996   5.756996           5.756996
# 3            3.392566             3.392566   3.392566           3.392566
# 4           15.161201            15.161201  15.161201          15.161201
#
#    Knoxville  Homewood South  Middle Hill    Oakwood  North Oakland  \
# 0   2.192827        2.192827     2.192827   2.192827       2.192827
# 1   0.117056        0.117056     0.117056   0.117056       0.117056
# 2   5.756996        5.756996     5.756996   5.756996       5.756996
# 3   3.392566        3.392566     3.392566   3.392566       3.392566
# 4  15.161201       15.161201    15.161201  15.161201      15.161201
#
#    Duquesne Heights  ...  Squirrel Hill South  Strip District  Swisshelm Park  \
# 0          2.192827  ...             2.192827        2.192827        2.192827
# 1          0.117056  ...             0.117056        0.117056        0.117056
# 2          5.756996  ...             5.756996        5.756996        5.756996
# 3          3.392566  ...             3.392566        3.392566        3.392566
# 4         15.161201  ...            15.161201       15.161201       15.161201
#
#    Perry South  Upper Lawrenceville  Regent Square  Terrace Village  \
# 0     2.192827             2.192827       2.192827         2.192827
# 1     0.117056             0.117056       0.117056         0.117056
# 2     5.756996             5.756996       5.756996         5.756996
# 3     3.392566             3.392566       3.392566         3.392566
# 4    15.161201            15.161201      15.161201        15.161201
#
#      Elliott  South Side Flats   Fineview
# 0   2.192827          2.192827   2.192827
# 1   0.117056          0.117056   0.117056
# 2   5.756996          5.756996   5.756996
# 3   3.392566          3.392566   3.392566
# 4  15.161201         15.161201  15.161201
#
# [5 rows x 90 columns]
